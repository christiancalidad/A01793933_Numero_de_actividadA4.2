# %% [markdown]
# ## Pytlint

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Flake 8

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Test and Coverage

# %% [markdown]
# ![image.png](attachment:image.png)
