# %% [markdown]
# ## Resultado de pruebas

# %% [markdown]
# ### TC1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### TC2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### TC3

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Uso Pylint

# %% [markdown]
# ### Antes

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Después

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Uso Flake8

# %% [markdown]
# ### Antes

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Después

# %% [markdown]
# ![image.png](attachment:image.png)
